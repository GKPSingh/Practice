# %%
# Importing the required libraries 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statistics

# %%
# Readling the data
df_cust = pd.read_csv('customers.csv')
df_cs =  pd.read_csv('credit_profiles.csv')
df_trans = pd.read_csv('transactions.csv')
pd.set_option("display.max_columns", None)

# %%
# Cheking the customer data
df_cust.head()
# Out:
#    cust_id            name  gender  age location      occupation  \
# 0        1   Manya Acharya  Female    2     City  Business Owner
# 1        2   Anjali Pandey  Female   47     City      Consultant
# 2        3  Aaryan Chauhan    Male   21     City      Freelancer
# 3        4      Rudra Bali    Male   24    Rural      Freelancer
# 4        5    Advait Malik    Male   48     City      Consultant
#
#    annual_income marital_status
# 0       358211.0        Married
# 1        65172.0         Single
# 2        22378.0        Married
# 3        33563.0        Married
# 4        39406.0        Married

# %%
#Checking the credit score data
df_cs.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit
# 0                             0.0       40000.0
# 1                             2.0        1250.0
# 2                             4.0        1000.0
# 3                             2.0        1000.0
# 4                             2.0       40000.0

# %%
# Cheking the transaction data
df_trans.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01           63  Flipkart        Electronics
# 1        2      385  2023-01-01           99   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01          471   Shopify             Sports
# 3        4      797  2023-01-01           33   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01           68    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
# Cheking the size of customer data
df_cust.shape
# Out:
# (1000, 8)

# %%
# Cheking the size of credit score data
df_cs.shape
# Out:
# (1004, 6)

# %%
# Cheking the size of transaction data
df_trans.shape
# Out:
# (500000, 7)

# %%
# More information of customer data
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000     950.000000
# mean    500.500000    36.405000  139410.314737
# std     288.819436    15.666155  112416.802007
# min       1.000000     1.000000       2.000000
# 25%     250.750000    26.000000   47627.500000
# 50%     500.500000    32.000000  112218.500000
# 75%     750.250000    46.000000  193137.500000
# max    1000.000000   135.000000  449346.000000

# %%
# Checking the null values in customer data
df_cust.isna().sum()
# Out:
# cust_id            0
# name               0
# gender             0
# age                0
# location           0
# occupation         0
# annual_income     50
# marital_status     0
# dtype: int64

# %%
# Checking the rows that have null annual_income
df_cust[df_cust.annual_income.isna()]
# Out:
#      cust_id               name  gender  age location           occupation  \
# 14        15      Sanjana Malik  Female   25    Rural               Artist
# 82        83  Reyansh Mukherjee    Male   27     City           Freelancer
# 97        98         Virat Puri    Male   47   Suburb       Business Owner
# 102      103         Aarav Shah    Male   32     City       Data Scientist
# 155      156       Kiaan Saxena    Male   24     City  Fullstack Developer
# 170      171       Advait Verma    Male   52     City       Business Owner
# 186      187       Samar Sardar    Male   53     City           Consultant
# 192      193        Ishan Joshi    Male   37   Suburb       Data Scientist
# 227      228   Advait Mukherjee    Male   48     City       Business Owner
# 232      233        Aditya Goel    Male   26     City           Freelancer
# 240      241        Aaryan Bose    Male   24   Suburb           Freelancer
# ...

# %%
# Occupation of the customers
df_cust.occupation.unique()
# Out:
# array(['Business Owner', 'Consultant', 'Freelancer',
#        'Fullstack Developer', 'Accountant', 'Data Scientist', 'Artist'],
#       dtype=object)

# %%
# Group by 'occupation' and calculate mean and median of 'annual_income'
income_stats = df_cust.groupby('occupation')['annual_income'].agg(['mean', 'median']).reset_index()

# Optionally round the values
income_stats['mean'] = income_stats['mean'].round(2)
income_stats['median'] = income_stats['median'].round(2)

print(income_stats)
# Out:
#             occupation       mean    median
# 0           Accountant   64123.56   65265.0
# 1               Artist   45267.69   45794.0
# 2       Business Owner  264976.87  261191.5
# 3           Consultant   58989.79   58017.0
# 4       Data Scientist  135524.22  135759.0
# 5           Freelancer   76990.48   46759.0
# 6  Fullstack Developer   78270.23   76774.0

# %%
# Filling null values for annual income with the median annual income
df_cust['annual_income'] = df_cust['annual_income'].fillna(
    df_cust.groupby('occupation')['annual_income'].transform('median'))

# %%
df_cust.isna().sum()
# Out:
# cust_id           0
# name              0
# gender            0
# age               0
# location          0
# occupation        0
# annual_income     0
# marital_status    0
# dtype: int64

# %%
# Cheking some filled rows for annual_income
df_cust.iloc[[14,82,97,102,155]]
# Out:
#      cust_id               name  gender  age location           occupation  \
# 14        15      Sanjana Malik  Female   25    Rural               Artist
# 82        83  Reyansh Mukherjee    Male   27     City           Freelancer
# 97        98         Virat Puri    Male   47   Suburb       Business Owner
# 102      103         Aarav Shah    Male   32     City       Data Scientist
# 155      156       Kiaan Saxena    Male   24     City  Fullstack Developer
#
#      annual_income marital_status
# 14         45794.0        Married
# 82         46759.0         Single
# 97        261191.5        Married
# 102       135759.0        Married
# 155        76774.0        Married

# %%
# checking the customer data
df_cust.head()
# Out:
#    cust_id            name  gender  age location      occupation  \
# 0        1   Manya Acharya  Female    2     City  Business Owner
# 1        2   Anjali Pandey  Female   47     City      Consultant
# 2        3  Aaryan Chauhan    Male   21     City      Freelancer
# 3        4      Rudra Bali    Male   24    Rural      Freelancer
# 4        5    Advait Malik    Male   48     City      Consultant
#
#    annual_income marital_status
# 0       358211.0        Married
# 1        65172.0         Single
# 2        22378.0        Married
# 3        33563.0        Married
# 4        39406.0        Married

# %%
# Histogram of annual income
plt.figure(figsize= (5,5))
sns.histplot(df_cust.annual_income, kde = True, color='blue', label = 'Data')
plt.title('Annual Income')
plt.show()

# %%
# Getting more inforation about the age and anuual_income
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000    1000.000000
# mean    500.500000    36.405000  138916.765500
# std     288.819436    15.666155  110969.408643
# min       1.000000     1.000000       2.000000
# 25%     250.750000    26.000000   48229.500000
# 50%     500.500000    32.000000  113416.000000
# 75%     750.250000    46.000000  192614.000000
# max    1000.000000   135.000000  449346.000000

# %%
# Customers having annual income less than 1000
df_cust[df_cust.annual_income<1000]
# Out:
#      cust_id            name  gender  age location           occupation  \
# 31        32     Veer Mistry    Male   50     City       Business Owner
# 262      263   Vivaan Tandon    Male   53   Suburb       Business Owner
# 316      317   Yuvraj Saxena    Male   47     City           Consultant
# 333      334    Avani Khanna  Female   29     City       Data Scientist
# 340      341     Priya Sinha  Female   33    Rural  Fullstack Developer
# 543      544    Advait Batra    Male   54     City           Consultant
# 592      593    Priya Gandhi  Female   32     City       Business Owner
# 633      634   Rudra Mehtani    Male   26     City       Data Scientist
# 686      687  Vihaan Jaiswal    Male   40     City       Business Owner
# 696      697      Ishan Negi    Male   47     City           Consultant
#
#      annual_income marital_status
# 31            50.0        Married
# 262           50.0        Married
# 316           50.0        Married
# 333           50.0        Married
# ...

# %%
# Replace income < 1000 with the median income per occupation
df_cust.loc[df_cust['annual_income'] < 1000, 'annual_income'] = (
    df_cust.groupby('occupation')['annual_income'].transform('median')
)

# %%
df_cust[df_cust.annual_income<1000]
# Out:
# Empty DataFrame
# Columns: [cust_id, name, gender, age, location, occupation, annual_income, marital_status]
# Index: []

# %%
# Checking the rows for updated annaul income
df_cust.iloc[[31,262,316,333,340]]
# Out:
#      cust_id           name  gender  age location           occupation  \
# 31        32    Veer Mistry    Male   50     City       Business Owner
# 262      263  Vivaan Tandon    Male   53   Suburb       Business Owner
# 316      317  Yuvraj Saxena    Male   47     City           Consultant
# 333      334   Avani Khanna  Female   29     City       Data Scientist
# 340      341    Priya Sinha  Female   33    Rural  Fullstack Developer
#
#      annual_income marital_status
# 31        261191.5        Married
# 262       261191.5        Married
# 316        58017.0        Married
# 333       135759.0        Married
# 340        76774.0        Married

# %%
# getting more information
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000    1000.000000
# mean    500.500000    36.405000  140483.548500
# std     288.819436    15.666155  110463.002934
# min       1.000000     1.000000    5175.000000
# 25%     250.750000    26.000000   49620.500000
# 50%     500.500000    32.000000  115328.000000
# 75%     750.250000    46.000000  195514.250000
# max    1000.000000   135.000000  449346.000000

# %%
# Checking if annual income is updated correctly
df_cust.at[696,'annual_income']
# Out:
# 58017.0

# %%
# Average Income per ocuupation
avg_income_per_occupation = df_cust.groupby('occupation')["annual_income"].mean()
avg_income_per_occupation
# Out:
# occupation
# Accountant              64123.562500
# Artist                  45309.236842
# Business Owner         268447.368512
# Consultant              60703.154639
# Data Scientist         137021.266304
# Freelancer              76327.508772
# Fullstack Developer     78727.972973
# Name: annual_income, dtype: float64

# %%
# Plotting the annual income per occupation
sns.barplot(avg_income_per_occupation, palette='tab10')
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/pn/ttr4mjfn1wn85j77m3skq0km0000gn/T/ipykernel_70996/4164575234.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(avg_income_per_occupation, palette='tab10')

# %%
# Plots for annual income as per different categories
category_columns = ['gender', 'location', 'occupation', 'marital_status']

# Set figure style
sns.set(style='whitegrid')

# Loop through each category
for col in category_columns:
    plt.figure(figsize=(10, 6))
    sns.barplot(
        data=df_cust,
        x=col,
        y='annual_income',
        estimator='mean',  # could also use median
        palette='tab10'
    )
    plt.title(f'Average Annual Income by {col.capitalize()}')
    plt.xticks(rotation=45)
    plt.ylabel('Average Annual Income')
    plt.xlabel(col.capitalize())
    plt.tight_layout()
    plt.show()
# Out:
# /var/folders/pn/ttr4mjfn1wn85j77m3skq0km0000gn/T/ipykernel_70996/1993796498.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /var/folders/pn/ttr4mjfn1wn85j77m3skq0km0000gn/T/ipykernel_70996/1993796498.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /var/folders/pn/ttr4mjfn1wn85j77m3skq0km0000gn/T/ipykernel_70996/1993796498.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /var/folders/pn/ttr4mjfn1wn85j77m3skq0km0000gn/T/ipykernel_70996/1993796498.py:10: FutureWarning:
#
# ...

# %%
# Copact way of looking at the average annual income per different categories
# Categorical columns to compare
category_columns = ['gender', 'location', 'occupation', 'marital_status']

# Set up the figure
fig, axes = plt.subplots(2, 2, figsize=(16, 12))  # 2x2 grid
axes = axes.flatten()  # To easily iterate

# Seaborn styling
sns.set(style='whitegrid')

# Plot for each category
for i, col in enumerate(category_columns):
    sns.barplot(
        data=df_cust,
        x=col,
        hue=col, 
        y='annual_income',
        estimator='mean',
        palette='tab10',
        ax=axes[i]
    )
    axes[i].set_title(f'Avg Annual Income by {col.capitalize()}')
    axes[i].set_xlabel(col.capitalize())
    axes[i].set_ylabel('Avg Income')
    axes[i].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
# Getting more info of the customer data
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000    1000.000000
# mean    500.500000    36.405000  140483.548500
# std     288.819436    15.666155  110463.002934
# min       1.000000     1.000000    5175.000000
# 25%     250.750000    26.000000   49620.500000
# 50%     500.500000    32.000000  115328.000000
# 75%     750.250000    46.000000  195514.250000
# max    1000.000000   135.000000  449346.000000

# %%
# Finding the size of the data where age is less than 18
df_cust[df_cust.age<18].shape
# Out:
# (7, 8)

# %%
# Finding the size of the data where age is more than 18
df_cust[df_cust.age>80].shape
# Out:
# (13, 8)

# %%
df_cust[(df_cust.age>64) & (df_cust.age<80)]
# Out:
# Empty DataFrame
# Columns: [cust_id, name, gender, age, location, occupation, annual_income, marital_status]
# Index: []

# %%
# size of the customer data
df_cust.shape
# Out:
# (1000, 8)

# %%
# size of the data having age greater than equal to 18 and less than equal to 64
df_cust[(df_cust.age>=18) & (df_cust.age<=64)].shape
# Out:
# (980, 8)

# %%
# Plotting the age Count 
age_dist = df_cust['age'].value_counts().sort_index()

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x=age_dist.index, y=age_dist.values, palette='viridis')
plt.title('Age Distribution by Range')
plt.xlabel('Age Range')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/pn/ttr4mjfn1wn85j77m3skq0km0000gn/T/ipykernel_70996/162681352.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=age_dist.index, y=age_dist.values, palette='viridis')

# %%
# Finding the mean and mode value of the age as per occupation
def get_mode(series):
    mode_vals = series.mode()
    return mode_vals.iloc[0] if not mode_vals.empty else None

# Group and calculate stats
age_stats = df_cust.groupby('occupation')['age'].agg(
    mean='mean',
    median='median',
    mode=get_mode
).reset_index()

# Optional: round numeric values
age_stats[['mean', 'median']] = age_stats[['mean', 'median']].round(2)

# Show result
print(age_stats)
# Out:
#             occupation   mean  median  mode
# 0           Accountant  34.81    31.5    26
# 1               Artist  28.24    26.0    26
# 2       Business Owner  49.74    51.0    55
# 3           Consultant  45.68    46.0    47
# 4       Data Scientist  33.16    32.0    29
# 5           Freelancer  25.18    24.0    21
# 6  Fullstack Developer  27.88    27.5    29

# %%
# Filling the outlier age values with the mode value of the age as per occupation
def get_mode(series):
    mode_vals = series.mode()
    return mode_vals.iloc[0] if not mode_vals.empty else None

# Compute mode age per occupation
mode_age_by_occ = df_cust.groupby('occupation')['age'].transform(get_mode)

# Define outlier condition
outliers = (df_cust['age'] < 18) | (df_cust['age'] > 80)

# Replace outlier ages with occupation-specific mode
df_cust.loc[outliers, 'age'] = mode_age_by_occ[outliers]

# %%
# Checking the update age values of the age
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000    1000.000000
# mean    500.500000    35.529000  140483.548500
# std     288.819436    12.326114  110463.002934
# min       1.000000    18.000000    5175.000000
# 25%     250.750000    26.000000   49620.500000
# 50%     500.500000    32.000000  115328.000000
# 75%     750.250000    44.250000  195514.250000
# max    1000.000000    64.000000  449346.000000

# %%
# Plotting the hist plot for the age
df_cust.age.plot(kind='hist',color = 'orange')
plt.show()

# %%
# creating the age_group column as per age range
bins = [18, 26, 49, 66]  # Note: right side is *exclusive* in pd.cut if right=False
labels = ['18-25', '26-48', '49-65']

# Create a new 'age_group' column
df_cust['age_group'] = pd.cut(df_cust['age'], bins=bins, labels=labels, right=False)

df_cust.head()
# Out:
#    cust_id            name  gender  age location      occupation  \
# 0        1   Manya Acharya  Female   55     City  Business Owner
# 1        2   Anjali Pandey  Female   47     City      Consultant
# 2        3  Aaryan Chauhan    Male   21     City      Freelancer
# 3        4      Rudra Bali    Male   24    Rural      Freelancer
# 4        5    Advait Malik    Male   48     City      Consultant
#
#    annual_income marital_status age_group
# 0       358211.0        Married     49-65
# 1        65172.0         Single     26-48
# 2        22378.0        Married     18-25
# 3        33563.0        Married     18-25
# 4        39406.0        Married     26-48

# %%
# Calculating the percentage of customer for each age group
age_group_counts = df_cust.age_group.value_counts(normalize=True)*100
age_group_counts
# Out:
# age_group
# 26-48    56.7
# 18-25    24.6
# 49-65    18.7
# Name: proportion, dtype: float64

# %%
type(age_group_counts)
# Out:
# pandas.core.series.Series

# %%
age_group_counts.index
# Out:
# CategoricalIndex(['26-48', '18-25', '49-65'], categories=['18-25', '26-48', '49-65'], ordered=True, dtype='category', name='age_group')

# %%
# Plotting the pie plot for percentage of customers in different age groups
plt.pie(age_group_counts,labels=age_group_counts.index, autopct = '%1.2f%%',shadow=True, explode=(0.1,0,0), startangle = 140)
plt.title('Distribution of Age Groups')
plt.show()

# %%
# Number of customers as per location
df_cust.location.value_counts()
# Out:
# location
# City      683
# Suburb    232
# Rural      85
# Name: count, dtype: int64

# %%
# Number of customers as per gender
df_cust.gender.value_counts()
# Out:
# gender
# Male      674
# Female    326
# Name: count, dtype: int64

# %%
# Grouping the customers as per gender and per location
customer_location_gender = df_cust.groupby(['location','gender']).size().unstack()
customer_location_gender
# Out:
# gender    Female  Male
# location
# City         226   457
# Rural         26    59
# Suburb        74   158

# %%
# Plotting the grouping of the customers as per gender and per location
customer_location_gender.plot(kind='bar',stacked = True, figsize = (10,5))
plt.title('Customer Distribution by Location and Gender')
plt.legend(title = 'Gender')
plt.xlabel('Location')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Exploring Credit Score Table

# %%
# Checkin the credit score
df_cs.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit
# 0                             0.0       40000.0
# 1                             2.0        1250.0
# 2                             4.0        1000.0
# 3                             2.0        1000.0
# 4                             2.0       40000.0

# %%
# Checking the number of rows and columns for credit score
df_cs.shape
# Out:
# (1004, 6)

# %%
# Checking the number of rows and columns for customer data
df_cust.shape
# Out:
# (1000, 9)

# %%
# Unique rows for credit score
df_cs.cust_id.nunique()
# Out:
# 1000

# %%
# Checking the duplicated rows
df_cs[df_cs['cust_id'].duplicated(keep=False)]
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 516      517           308                 NaN               NaN
# 517      517           308            0.113860              33.0
# 569      569           344                 NaN               NaN
# 570      569           344            0.112599              37.0
# 607      606           734                 NaN               NaN
# 608      606           734            0.193418            4392.0
# 664      662           442                 NaN               NaN
# 665      662           442            0.856039             266.0
#
#      credit_inquiries_last_6_months  credit_limit
# 516                             NaN           NaN
# 517                             3.0         500.0
# 569                             NaN           NaN
# 570                             0.0         500.0
# 607                             NaN           NaN
# 608                             1.0       40000.0
# ...

# %%
# Dropping the duplicate rows in the credit score
df_cs = df_cs.drop_duplicates(subset='cust_id',keep='last')
df_cs.shape
# Out:
# (1000, 6)

# %%
# Checking if duplicate rows in the credit score
df_cs[df_cs['cust_id'].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [cust_id, credit_score, credit_utilisation, outstanding_debt, credit_inquiries_last_6_months, credit_limit]
# Index: []

# %%
# Checking the null values in the credit score
df_cs.isna().sum()
# Out:
# cust_id                            0
# credit_score                       0
# credit_utilisation                 0
# outstanding_debt                   0
# credit_inquiries_last_6_months     0
# credit_limit                      65
# dtype: int64

# %%
#Checking the credit score
df_cs.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit
# 0                             0.0       40000.0
# 1                             2.0        1250.0
# 2                             4.0        1000.0
# 3                             2.0        1000.0
# 4                             2.0       40000.0

# %%
# checking the credit score
df_cs.credit_limit.value_counts()
# Out:
# credit_limit
# 500.0      229
# 60000.0    186
# 40000.0    137
# 1500.0     100
# 1000.0      90
# 750.0       76
# 1250.0      75
# 20000.0     42
# Name: count, dtype: int64

# %%
# Plotting the credit score and credit limit
plt.figure(figsize=(20,5))
plt.scatter(df_cs.credit_limit, df_cs.credit_score, c='blue', marker = '+', label = 'Data Point')
plt.title('Credit Score vs Credit Limit')
plt.xlabel('Credit Limit')
plt.ylabel('Credit Score')

#plt.xticks(range(0,90001,5000))
plt.grid(True)
plt.legend()
plt.show()

# %%
# Creating the Credit score range column as per the ranges
bins = [300, 450, 500, 550, 600, 650, 700, 750,800]  # Note: right side is *exclusive* in pd.cut if right=False
labels = [f'{start}-{end-1}' for start, end in zip(bins,bins[1:])] 

# Create a new 'credit_score_group' column
df_cs['credit_score_range'] = pd.cut(df_cs['credit_score'], bins=bins, labels=labels, include_lowest =True, right=False)

df_cs.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit credit_score_range
# 0                             0.0       40000.0            700-749
# 1                             2.0        1250.0            550-599
# 2                             4.0        1000.0            500-549
# 3                             2.0        1000.0            500-549
# 4                             2.0       40000.0            700-749

# %%
# Checking the infomation for credit_score_range between 700-749
df_cs[df_cs.credit_score_range=='700-749']
# Out:
#       cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0           1           749            0.585171           19571.0
# 4           5           708            0.586151           18090.0
# 6           7           747            0.523965           15544.0
# 16         17           702            0.894423           18444.0
# 27         28           729            0.149748            3453.0
# ...       ...           ...                 ...               ...
# 969       966           720            0.203742            6159.0
# 970       967           739            0.845474           23929.0
# 991       988           739            0.435891            9283.0
# 994       991           709            0.718484           15473.0
# 1002      999           725            0.249670            6973.0
#
#       credit_inquiries_last_6_months  credit_limit credit_score_range
# 0                                0.0       40000.0            700-749
# ...

# %%
# Getting a mode value for credit_limit as per credit_score_range
mode_df = df_cs.groupby('credit_score_range')['credit_limit'].agg(lambda x: x.mode().iloc[0]).reset_index()
mode_df
# Out:
# /var/folders/pn/ttr4mjfn1wn85j77m3skq0km0000gn/T/ipykernel_70996/2094918314.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_df = df_cs.groupby('credit_score_range')['credit_limit'].agg(lambda x: x.mode().iloc[0]).reset_index()
#   credit_score_range  credit_limit
# 0            300-449         500.0
# 1            450-499         750.0
# 2            500-549        1000.0
# 3            550-599        1250.0
# 4            600-649        1500.0
# 5            650-699       20000.0
# 6            700-749       40000.0
# 7            750-799       60000.0

# %%
# Checking Null values in the credit score data
df_cs.isna().sum()
# Out:
# cust_id                            0
# credit_score                       0
# credit_utilisation                 0
# outstanding_debt                   0
# credit_inquiries_last_6_months     0
# credit_limit                      65
# credit_score_range                 0
# dtype: int64

# %%
# Merging the credit score data and mode_df
df_cs_merged = pd.merge(df_cs, mode_df, on = 'credit_score_range', suffixes = ("", "_mode"))
df_cs_merged
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0          1           749            0.585171           19571.0
# 1          2           587            0.107928          161644.0
# 2          3           544            0.854807             513.0
# 3          4           504            0.336938             224.0
# 4          5           708            0.586151           18090.0
# ..       ...           ...                 ...               ...
# 995      996           564            0.702963             688.0
# 996      997           774            0.465462           17139.0
# 997      998           529            0.585856             386.0
# 998      999           725            0.249670            6973.0
# 999     1000           775            0.696050           33956.0
#
#      credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 0                               0.0       40000.0            700-749
# ...

# %%
# Checking the null values in the credit_limit data
df_cs_merged[df_cs_merged.credit_limit.isna()].head()
# Out:
#     cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 10       11           679            0.557450            9187.0
# 35       36           790            0.112535            4261.0
# 37       38           514            0.296971             238.0
# 45       46           761            0.596041           24234.0
# 64       65           734            0.473715           13631.0
#
#     credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 10                             2.0           NaN            650-699
# 35                             1.0           NaN            750-799
# 37                             2.0           NaN            500-549
# 45                             2.0           NaN            750-799
# 64                             0.0           NaN            700-749
#
#     credit_limit_mode
# 10            20000.0
# 35            60000.0
# 37             1000.0
# 45            60000.0
# 64            40000.0

# %%
# Filling the null values in the credit_limit with the mode values 
df_cs_merged['credit_limit'].fillna(df_cs_merged['credit_limit_mode'], inplace=True)
# Out:
# /var/folders/pn/ttr4mjfn1wn85j77m3skq0km0000gn/T/ipykernel_70996/2368935223.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cs_merged['credit_limit'].fillna(df_cs_merged['credit_limit_mode'], inplace=True)

# %%
# Checking the null values in the merged data
df_cs_merged[df_cs_merged.credit_limit.isna()].head()
# Out:
# Empty DataFrame
# Columns: [cust_id, credit_score, credit_utilisation, outstanding_debt, credit_inquiries_last_6_months, credit_limit, credit_score_range, credit_limit_mode]
# Index: []

# %%
# Merging the df_cs_merged data into credit score data
df_cs = df_cs_merged.copy()
df_cs.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 0                             0.0       40000.0            700-749
# 1                             2.0        1250.0            550-599
# 2                             4.0        1000.0            500-549
# 3                             2.0        1000.0            500-549
# 4                             2.0       40000.0            700-749
#
#    credit_limit_mode
# 0            40000.0
# 1             1250.0
# 2             1000.0
# 3             1000.0
# 4            40000.0

# %%
# Checking the rows to confirm if they have now populated
df_cs.loc[[10,35,37,45,64]]
# Out:
#     cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 10       11           679            0.557450            9187.0
# 35       36           790            0.112535            4261.0
# 37       38           514            0.296971             238.0
# 45       46           761            0.596041           24234.0
# 64       65           734            0.473715           13631.0
#
#     credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 10                             2.0       20000.0            650-699
# 35                             1.0       60000.0            750-799
# 37                             2.0        1000.0            500-549
# 45                             2.0       60000.0            750-799
# 64                             0.0       40000.0            700-749
#
#     credit_limit_mode
# 10            20000.0
# 35            60000.0
# 37             1000.0
# 45            60000.0
# 64            40000.0

# %%
# Getting more information
df_cs.describe()
# Out:
#            cust_id  credit_score  credit_utilisation  outstanding_debt  \
# count  1000.000000   1000.000000         1000.000000       1000.000000
# mean    500.500000    589.182000            0.498950       9683.597000
# std     288.819436    152.284929            0.233139      25255.893671
# min       1.000000    300.000000            0.103761         33.000000
# 25%     250.750000    460.000000            0.293917        221.000000
# 50%     500.500000    601.500000            0.487422        550.000000
# 75%     750.250000    738.000000            0.697829      11819.500000
# max    1000.000000    799.000000            0.899648     209901.000000
#
#        credit_inquiries_last_6_months  credit_limit  credit_limit_mode
# count                     1000.000000    1000.00000        1000.000000
# mean                         1.955000   19733.75000       19912.500000
# std                          1.414559   24717.43818       24840.914633
# ...

# %%
# Box plot for outstanding_debt
sns.boxplot(df_cs.outstanding_debt)
# Out:
# <Axes: ylabel='outstanding_debt'>

# %%
# Checking if outstanding_debt is greater than the credit_limit
df_cs[df_cs.outstanding_debt>df_cs.credit_limit]
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 1          2           587            0.107928          161644.0
# 19        20           647            0.439132          205014.0
# 25        26           758            0.250811          190838.0
# 38        39           734            0.573023          122758.0
# 93        94           737            0.739948          137058.0
# 204      205           303            0.364360          187849.0
# 271      272           703            0.446886          154568.0
# 301      302           722            0.608076          122402.0
# 330      331           799            0.363420          208898.0
# 350      351           320            0.285081          150860.0
# 446      447           754            0.178394          206191.0
# 544      545           764            0.337769          135112.0
# 636      637           420            0.323984          140063.0
# ...

# %%
# Making the outstanding_debt value equal to credit limit 
df_cs.loc[df_cs.outstanding_debt>df_cs.credit_limit, 'outstanding_debt'] = df_cs['credit_limit']

# %%
# Checkin if there is still any data where outstanding_debt>credit_limit
df_cs[df_cs.outstanding_debt>df_cs.credit_limit]
# Out:
# Empty DataFrame
# Columns: [cust_id, credit_score, credit_utilisation, outstanding_debt, credit_inquiries_last_6_months, credit_limit, credit_score_range, credit_limit_mode]
# Index: []

# %%
# Checking the credit score data
df_cs.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928            1250.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 0                             0.0       40000.0            700-749
# 1                             2.0        1250.0            550-599
# 2                             4.0        1000.0            500-549
# 3                             2.0        1000.0            500-549
# 4                             2.0       40000.0            700-749
#
#    credit_limit_mode
# 0            40000.0
# 1             1250.0
# 2             1000.0
# 3             1000.0
# 4            40000.0

# %%
# Checking the customer data 
df_cust.head()
# Out:
#    cust_id            name  gender  age location      occupation  \
# 0        1   Manya Acharya  Female   55     City  Business Owner
# 1        2   Anjali Pandey  Female   47     City      Consultant
# 2        3  Aaryan Chauhan    Male   21     City      Freelancer
# 3        4      Rudra Bali    Male   24    Rural      Freelancer
# 4        5    Advait Malik    Male   48     City      Consultant
#
#    annual_income marital_status age_group
# 0       358211.0        Married     49-65
# 1        65172.0         Single     26-48
# 2        22378.0        Married     18-25
# 3        33563.0        Married     18-25
# 4        39406.0        Married     26-48

# %%
# Merging the customer data with the credit score data 
df_cust_cs = df_cust.merge(df_cs, on='cust_id', how='inner')
df_cust_cs.head()
# Out:
#    cust_id            name  gender  age location      occupation  \
# 0        1   Manya Acharya  Female   55     City  Business Owner
# 1        2   Anjali Pandey  Female   47     City      Consultant
# 2        3  Aaryan Chauhan    Male   21     City      Freelancer
# 3        4      Rudra Bali    Male   24    Rural      Freelancer
# 4        5    Advait Malik    Male   48     City      Consultant
#
#    annual_income marital_status age_group  credit_score  credit_utilisation  \
# 0       358211.0        Married     49-65           749            0.585171
# 1        65172.0         Single     26-48           587            0.107928
# 2        22378.0        Married     18-25           544            0.854807
# 3        33563.0        Married     18-25           504            0.336938
# 4        39406.0        Married     26-48           708            0.586151
#
#    outstanding_debt  credit_inquiries_last_6_months  credit_limit  \
# ...

# %%
df_cust_cs.isna().sum()
# Out:
# cust_id                           0
# name                              0
# gender                            0
# age                               0
# location                          0
# occupation                        0
# annual_income                     0
# marital_status                    0
# age_group                         0
# credit_score                      0
# credit_utilisation                0
# outstanding_debt                  0
# credit_inquiries_last_6_months    0
# credit_limit                      0
# credit_score_range                0
# credit_limit_mode                 0
# dtype: int64

# %%
# Finding the correation between the different numerical columns
numerical_cols = ['credit_score','credit_utilisation', 'outstanding_debt','credit_limit','annual_income','age']
correlation_matrix = df_cust_cs[numerical_cols].corr()
sns.heatmap(correlation_matrix, annot = True, fmt =".2f", cmap='coolwarm',linewidths=0.8)
plt.show()

# %%
# Checking the trans data
df_trans.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01           63  Flipkart        Electronics
# 1        2      385  2023-01-01           99   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01          471   Shopify             Sports
# 3        4      797  2023-01-01           33   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01           68    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
# number of rows and columns in the transaction data
df_trans.shape
# Out:
# (500000, 7)

# %%
# More information about the transaction data
df_trans.describe()
# Out:
#              tran_id        cust_id   tran_amount
# count  500000.000000  500000.000000  500000.00000
# mean   250000.500000     501.400428    3225.20733
# std    144337.711634     288.641924   13098.74276
# min         1.000000       1.000000       0.00000
# 25%    125000.750000     252.000000      64.00000
# 50%    250000.500000     502.000000     141.00000
# 75%    375000.250000     752.000000     397.00000
# max    500000.000000    1000.000000   69999.00000

# %%
# Checking for null values
df_trans.isna().sum()
# Out:
# tran_id                0
# cust_id                0
# tran_date              0
# tran_amount            0
# platform            4941
# product_category       0
# payment_type           0
# dtype: int64

# %%
# checking the null 'platform' data
df_trans[df_trans['platform'].isna()]
# Out:
#         tran_id  cust_id   tran_date  tran_amount platform   product_category  \
# 355         356       58  2023-01-01          237      NaN        Electronics
# 418         419      383  2023-01-01          338      NaN        Electronics
# 607         608      421  2023-01-01          700      NaN        Electronics
# 844         845      945  2023-01-01          493      NaN             Sports
# 912         913      384  2023-01-01           85      NaN  Fashion & Apparel
# ...         ...      ...         ...          ...      ...                ...
# 499579   499580      924  2023-09-05           31      NaN  Fashion & Apparel
# 499646   499647      944  2023-09-05        58445      NaN  Fashion & Apparel
# 499725   499726      620  2023-09-05           15      NaN             Sports
# 499833   499834      616  2023-09-05           97      NaN  Fashion & Apparel
# 499997   499998       57  2023-09-05          224      NaN   Garden & Outdoor
#
#        payment_type
# ...

# %%
# Getting the unique values of platform used
df_trans.platform.unique()
# Out:
# array(['Flipkart', 'Alibaba', 'Shopify', 'Amazon', 'Ebay', 'Meesho',
#        'Cred', nan], dtype=object)

# %%
# getting the product information
df_trans.product_category.unique()
# Out:
# array(['Electronics', 'Fashion & Apparel', 'Sports', 'Kitchen Appliances',
#        'Beauty & Personal Care', 'Garden & Outdoor', 'Books',
#        'Home Decor', 'Toys & Games'], dtype=object)

# %%
# Number of times different Platform are used
df_trans.platform.value_counts()
# Out:
# platform
# Amazon      151443
# Flipkart    122660
# Alibaba      73584
# Meesho       73271
# Shopify      39416
# Cred         24741
# Ebay          9944
# Name: count, dtype: int64

# %%
# Products bought per platform
sns.countplot(y= 'product_category',hue= 'platform', data=df_trans)
# Out:
# <Axes: xlabel='count', ylabel='product_category'>

# %%
# Majority platform used
df_trans.platform.mode()[0]
# Out:
# 'Amazon'

# %%
# Filling the null vaules in the platform column with the amazon 
df_trans.platform.fillna(df_trans.platform.mode()[0],inplace=True)
# Out:
# /var/folders/pn/ttr4mjfn1wn85j77m3skq0km0000gn/T/ipykernel_70996/3689182329.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_trans.platform.fillna(df_trans.platform.mode()[0],inplace=True)

# %%
# Checking for null values
df_trans.isna().sum()
# Out:
# tran_id             0
# cust_id             0
# tran_date           0
# tran_amount         0
# platform            0
# product_category    0
# payment_type        0
# dtype: int64

# %%
# Checking for '0' transaction amount
df_trans[df_trans.tran_amount==0]
# Out:
#         tran_id  cust_id   tran_date  tran_amount platform product_category  \
# 120         121      440  2023-01-01            0   Amazon      Electronics
# 141         142      839  2023-01-01            0   Amazon      Electronics
# 517         518      147  2023-01-01            0   Amazon      Electronics
# 533         534      891  2023-01-01            0   Amazon      Electronics
# 586         587      108  2023-01-01            0   Amazon      Electronics
# ...         ...      ...         ...          ...      ...              ...
# 499326   499327      695  2023-09-05            0   Amazon      Electronics
# 499494   499495      295  2023-09-05            0   Amazon      Electronics
# 499708   499709      141  2023-09-05            0   Amazon      Electronics
# 499928   499929        4  2023-09-05            0   Amazon      Electronics
# 499972   499973      224  2023-09-05            0   Amazon      Electronics
#
#        payment_type
# 120     Credit Card
# ...

# %%
# Creating a new data set for tran_amount =0
df_trans_zero = df_trans[df_trans.tran_amount==0]
df_trans_zero.head()
# Out:
#      tran_id  cust_id   tran_date  tran_amount platform product_category  \
# 120      121      440  2023-01-01            0   Amazon      Electronics
# 141      142      839  2023-01-01            0   Amazon      Electronics
# 517      518      147  2023-01-01            0   Amazon      Electronics
# 533      534      891  2023-01-01            0   Amazon      Electronics
# 586      587      108  2023-01-01            0   Amazon      Electronics
#
#     payment_type
# 120  Credit Card
# 141  Credit Card
# 517  Credit Card
# 533  Credit Card
# 586  Credit Card

# %%
# checking the size of the data
df_trans_zero.shape
# Out:
# (4734, 7)

# %%
# Numbers if record having the '0' value
df_trans_zero.tran_amount.value_counts()
# Out:
# tran_amount
# 0    4734
# Name: count, dtype: int64

# %%
#Product category when value tran_amount is '0'
df_trans_zero.product_category.value_counts()
# Out:
# product_category
# Electronics    4734
# Name: count, dtype: int64

# %%
# payment info when trans_amount is '0'
df_trans_zero.payment_type.value_counts()
# Out:
# payment_type
# Credit Card    4734
# Name: count, dtype: int64

# %%
# Getting the data when platform is 'amazon'and  product_category is'Electronics' and payment_type is'Credit Card'
df_trans_1 = df_trans[(df_trans.platform=='Amazon')&(df_trans.product_category=='Electronics')&(df_trans.payment_type=='Credit Card')]
df_trans_1.head()
# Out:
#      tran_id  cust_id   tran_date  tran_amount platform product_category  \
# 109      110      887  2023-01-01          635   Amazon      Electronics
# 120      121      440  2023-01-01            0   Amazon      Electronics
# 141      142      839  2023-01-01            0   Amazon      Electronics
# 173      174      676  2023-01-01        60439   Amazon      Electronics
# 190      191      763  2023-01-01          697   Amazon      Electronics
#
#     payment_type
# 109  Credit Card
# 120  Credit Card
# 141  Credit Card
# 173  Credit Card
# 190  Credit Card

# %%
# finding the median value
median_to_replace = df_trans_1[df_trans_1.tran_amount>0].tran_amount.median()
median_to_replace
# Out:
# 554.0

# %%
# Replacing the '0' value with the median value
df_trans['tran_amount'].replace(0,median_to_replace, inplace=True)
# Out:
# /var/folders/pn/ttr4mjfn1wn85j77m3skq0km0000gn/T/ipykernel_70996/1060333583.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_trans['tran_amount'].replace(0,median_to_replace, inplace=True)

# %%
# Getting info about the data
df_trans.describe()
# Out:
#              tran_id        cust_id    tran_amount
# count  500000.000000  500000.000000  500000.000000
# mean   250000.500000     501.400428    3230.452602
# std    144337.711634     288.641924   13097.561071
# min         1.000000       1.000000       2.000000
# 25%    125000.750000     252.000000      66.000000
# 50%    250000.500000     502.000000     146.000000
# 75%    375000.250000     752.000000     413.000000
# max    500000.000000    1000.000000   69999.000000

# %%
# Plotting the histogram for tran_amount data
sns.histplot(df_trans.tran_amount, bins=30)
# Out:
# <Axes: xlabel='tran_amount', ylabel='Count'>

# %%
# Records where tran_amount>10000
(df_trans.tran_amount>10000).value_counts()
# Out:
# tran_amount
# False    475000
# True      25000
# Name: count, dtype: int64

# %%
# Hist plot for data having tran_amount<10000
sns.histplot(df_trans[df_trans.tran_amount<10000].tran_amount, bins=30, color='green')
# Out:
# <Axes: xlabel='tran_amount', ylabel='Count'>

# %%
# Finding lower and upper quantile limit
Q1, Q3 = df_trans['tran_amount'].quantile([0.25,0.75])
IQR = Q3 - Q1

lower = Q1 - 2*IQR
upper = Q3 + 2*IQR
lower, upper
# Out:
# (-628.0, 1107.0)

# %%
# size of data where tran_amount>=upper
df_trans_outliers = df_trans[df_trans.tran_amount>=upper]
df_trans_outliers.shape
# Out:
# (25000, 7)

# %%
# creating data where tran_amount<upper
df_trans_normal = df_trans[df_trans.tran_amount<upper]
df_trans_normal.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01           63  Flipkart        Electronics
# 1        2      385  2023-01-01           99   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01          471   Shopify             Sports
# 3        4      797  2023-01-01           33   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01           68    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
# Getting mean values of transactions for each product
tran_mean_per_category = df_trans_normal.groupby('product_category')['tran_amount'].mean()
tran_mean_per_category
# Out:
# product_category
# Beauty & Personal Care     92.167205
# Books                      29.553515
# Electronics               510.172685
# Fashion & Apparel          64.553463
# Garden & Outdoor          125.630277
# Home Decor                302.487561
# Kitchen Appliances        176.773288
# Sports                    269.181631
# Toys & Games               50.333298
# Name: tran_amount, dtype: float64

# %%
# Filling the outliers values with the mean value as per product mean
df_trans.loc[df_trans_outliers.index,'tran_amount'] = df_trans_outliers['product_category'].map(tran_mean_per_category)
# Out:
# /var/folders/pn/ttr4mjfn1wn85j77m3skq0km0000gn/T/ipykernel_70996/1557641253.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 92.16720517  50.33329759 176.77328782 ... 269.18163136 269.18163136
#   64.55346325]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_trans.loc[df_trans_outliers.index,'tran_amount'] = df_trans_outliers['product_category'].map(tran_mean_per_category)

# %%
# Checking the outlier data if all are populated or not
df_trans.loc[df_trans_outliers.index]
# Out:
#         tran_id  cust_id   tran_date  tran_amount  platform  \
# 26           27      380  2023-01-01    92.167205   Shopify
# 49           50      287  2023-01-01    50.333298    Amazon
# 94           95      770  2023-01-01   176.773288      Ebay
# 104         105      549  2023-01-01    64.553463  Flipkart
# 113         114      790  2023-01-01   176.773288   Shopify
# ...         ...      ...         ...          ...       ...
# 499742   499743      868  2023-09-05    64.553463    Meesho
# 499888   499889      614  2023-09-05    64.553463    Meesho
# 499900   499901      811  2023-09-05   269.181631  Flipkart
# 499966   499967      662  2023-09-05   269.181631    Meesho
# 499996   499997      569  2023-09-05    64.553463    Meesho
#
#               product_category payment_type
# 26      Beauty & Personal Care  Credit Card
# 49                Toys & Games         Gpay
# 94          Kitchen Appliances  Credit Card
# 104          Fashion & Apparel         Gpay
# ...

# %%
# Checking the transaction data
df_trans.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01         63.0  Flipkart        Electronics
# 1        2      385  2023-01-01         99.0   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01        471.0   Shopify             Sports
# 3        4      797  2023-01-01         33.0   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01         68.0    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
# plotting the histogra for tran_amount
sns.histplot(df_trans.tran_amount, kde=True, bins=20, color = 'blue' )
# Out:
# <Axes: xlabel='tran_amount', ylabel='Count'>

# %%
# Count plot for calculating the percentage of payment_type used
sns.countplot(x=df_trans.payment_type,color ='orange', stat='percent');

# %%
# Checking the customer data
df_cust.head()
# Out:
#    cust_id            name  gender  age location      occupation  \
# 0        1   Manya Acharya  Female   55     City  Business Owner
# 1        2   Anjali Pandey  Female   47     City      Consultant
# 2        3  Aaryan Chauhan    Male   21     City      Freelancer
# 3        4      Rudra Bali    Male   24    Rural      Freelancer
# 4        5    Advait Malik    Male   48     City      Consultant
#
#    annual_income marital_status age_group
# 0       358211.0        Married     49-65
# 1        65172.0         Single     26-48
# 2        22378.0        Married     18-25
# 3        33563.0        Married     18-25
# 4        39406.0        Married     26-48

# %%
# Checking the transaction data
df_trans.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01         63.0  Flipkart        Electronics
# 1        2      385  2023-01-01         99.0   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01        471.0   Shopify             Sports
# 3        4      797  2023-01-01         33.0   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01         68.0    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
# Checking the merged data for customer and credit score
df_cust_cs.head()
# Out:
#    cust_id            name  gender  age location      occupation  \
# 0        1   Manya Acharya  Female   55     City  Business Owner
# 1        2   Anjali Pandey  Female   47     City      Consultant
# 2        3  Aaryan Chauhan    Male   21     City      Freelancer
# 3        4      Rudra Bali    Male   24    Rural      Freelancer
# 4        5    Advait Malik    Male   48     City      Consultant
#
#    annual_income marital_status age_group  credit_score  credit_utilisation  \
# 0       358211.0        Married     49-65           749            0.585171
# 1        65172.0         Single     26-48           587            0.107928
# 2        22378.0        Married     18-25           544            0.854807
# 3        33563.0        Married     18-25           504            0.336938
# 4        39406.0        Married     26-48           708            0.586151
#
#    outstanding_debt  credit_inquiries_last_6_months  credit_limit  \
# ...

# %%
# Merging the customer_creditscore data with the transaction data
df = pd.merge(df_cust_cs, df_trans, on = 'cust_id',how='inner')
df.head(10)
# Out:
#    cust_id           name  gender  age location      occupation  \
# 0        1  Manya Acharya  Female   55     City  Business Owner
# 1        1  Manya Acharya  Female   55     City  Business Owner
# 2        1  Manya Acharya  Female   55     City  Business Owner
# 3        1  Manya Acharya  Female   55     City  Business Owner
# 4        1  Manya Acharya  Female   55     City  Business Owner
# 5        1  Manya Acharya  Female   55     City  Business Owner
# 6        1  Manya Acharya  Female   55     City  Business Owner
# 7        1  Manya Acharya  Female   55     City  Business Owner
# 8        1  Manya Acharya  Female   55     City  Business Owner
# 9        1  Manya Acharya  Female   55     City  Business Owner
#
#    annual_income marital_status age_group  credit_score  credit_utilisation  \
# 0       358211.0        Married     49-65           749            0.585171
# 1       358211.0        Married     49-65           749            0.585171
# ...

# %%
# Checking the size of the data
df.shape
# Out:
# (500000, 22)

# %%
# Plot of Payment distribution per Age group
plt.figure(figsize=(10, 6))
sns.set(style='whitegrid')
sns.countplot(x = 'age_group',hue='payment_type', data = df,palette='Set1')
plt.title('Payment Type Distribution Across Age Groups', fontsize=14)
plt.xlabel('Age Group', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.legend(title='Payment Type', title_fontsize=11)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Plotting the Product Category and Platform counts as per Age Group
fig,(ax1, ax2)= plt.subplots(1,2,figsize=(15,6))

sns.countplot(x='age_group', hue='product_category',data=df, ax=ax1)
ax1.set_title('Product Category Count by Age Group', fontsize=14)
ax1.set_xlabel('Age Group', fontsize=12)
ax1.set_ylabel('Count', fontsize=12)
ax1.legend(title='Product Category', title_fontsize=11, loc='upper right')

sns.countplot(x='age_group', hue='platform',data=df, ax=ax2)
ax2.set_title('Platform Count by Age Group', fontsize=14)
ax2.set_xlabel('Age Group', fontsize=12)
ax2.set_ylabel('Count', fontsize=12)
ax2.legend(title='Product Category', title_fontsize=11, loc='upper right')
plt.show()

# %%
# Plotting the 'payment_type', 'platform', 'product_category', 'marital_status', 'age_group' as per mean trans_amount

# Category columns to analyze
category_columns = ['payment_type', 'platform', 'product_category', 'marital_status', 'age_group']

# Setup subplots
fig, axes = plt.subplots(3, 2, figsize=(20, 20))
axes = axes.flatten()

sns.set(style='whitegrid')

for i, col in enumerate(category_columns):
    # Compute mean transaction amount per category and sort
    sorted_data = (
        df.groupby(col, observed=True)['tran_amount']
        .mean()
        .sort_values(ascending=False)
        .reset_index()
    )

    sns.barplot(
        data=sorted_data,
        x=col,
        y='tran_amount',
        hue=col,
        palette='tab10',
        ax=axes[i]
    )

    axes[i].set_title(f'Avg Transaction Amount by {col.replace("_", " ").title()}', fontsize=13)
    axes[i].set_xlabel(col.replace("_", " ").title())
    axes[i].set_ylabel('Avg Transaction Amount')
    axes[i].tick_params(axis='x', rotation=45)

# Remove any unused subplot
for j in range(len(category_columns), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
# Checking the data
df.head()
# Out:
#    cust_id           name  gender  age location      occupation  \
# 0        1  Manya Acharya  Female   55     City  Business Owner
# 1        1  Manya Acharya  Female   55     City  Business Owner
# 2        1  Manya Acharya  Female   55     City  Business Owner
# 3        1  Manya Acharya  Female   55     City  Business Owner
# 4        1  Manya Acharya  Female   55     City  Business Owner
#
#    annual_income marital_status age_group  credit_score  credit_utilisation  \
# 0       358211.0        Married     49-65           749            0.585171
# 1       358211.0        Married     49-65           749            0.585171
# 2       358211.0        Married     49-65           749            0.585171
# 3       358211.0        Married     49-65           749            0.585171
# 4       358211.0        Married     49-65           749            0.585171
#
#    outstanding_debt  credit_inquiries_last_6_months  credit_limit  \
# ...

# %%
# Plotting the average 'annual_income', 'credit_limit', 'credit_score' per Age_group
# Correct list of numeric columns
category_columns = ['annual_income', 'credit_limit', 'credit_score']

# Set up the subplots
fig, axes = plt.subplots(1, 3, figsize=(20, 6))  # 1 row, 3 columns
sns.set(style='whitegrid')

# Loop through each numeric column
for i, col in enumerate(category_columns):
    # Compute mean values grouped by age_group
    grouped_data = df.groupby('age_group', observed=True)[col].mean().reset_index()

    # Plotting
    sns.barplot(
        data=grouped_data,
        x='age_group',
        y=col,
        hue='age_group',
        palette='Set1',
        ax=axes[i]
    )

    axes[i].set_title(f'Average {col.replace("_", " ").title()} by Age Group',fontsize=20)
    axes[i].set_xlabel('Age Group',fontsize=16)
    axes[i].set_ylabel(f'Average {col.replace("_", " ").title()}',fontsize=16)
    axes[i].tick_params(axis='x', rotation=45, labelsize=16)

plt.tight_layout()
plt.show()
